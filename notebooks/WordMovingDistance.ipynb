# %%
import spacy
import gensim
import xml.etree.ElementTree as ET

# %%
print(f'gensim version: {gensim.__version__}')
glove_model = gensim.models.KeyedVectors.load_word2vec_format('data/glove.6B.50d.txt')
spacy_nlp = spacy.load('en_core_web_sm')
# Out:
# gensim version: 4.1.2

# %%
qa = ET.parse('../data/CRF_training/qa_test.xml')
root = qa.getroot()

# %%
def wmd(qa_pair):
    """
        Function used to compute Word Moving Distance between question and each candidate
    """
    
    qa_pair_tokens = []
    for item in qa_pair:
        qa_pair_tokens.append([token.text.lower() for token in spacy_nlp(item) if not token.is_stop])
    
    question = qa_pair[0]
    question_tokens =  qa_pair_tokens[0]
    
    print(f'\nQuestion: {question}\n')
    for candidate_tokens, candidate in zip(qa_pair_tokens, qa_pair):
        print('-' * 50)
        print(f'Comparing to: {candidate}')
        dist = glove_model.wmdistance(question_tokens, candidate_tokens)
        print(f'distance = {dist:.4f}')

# %%
pair = []
for qa_pair in root:
        pair = []
        pair = [qa_pair.find('question').text.split('\n')[1].strip()]
        pair.extend([candidate.text.split('\n')[1].strip() for candidate in qa_pair.findall('candidate')])
        
        wmd(pair)
# Out:
# Question: which course has been viewed by MA and MH ?
#
# --------------------------------------------------
# Comparing to: which course has been viewed by MA and MH ?
# distance = 0.0000
# --------------------------------------------------
# Comparing to: MA has viewed course CS260 Human Computer Interaction
# distance = 0.6091
# --------------------------------------------------
# Comparing to: MH has viewed course CS260 Human Computer Interaction and MA has viewed course CS260 Human Computer Interaction
# distance = 0.5834
# --------------------------------------------------
# Comparing to: ANB has viewed course CS260 Human Computer Interaction
# distance = 0.7755
#
# Question: which course has been viewed by SA ?
#
# --------------------------------------------------
# Comparing to: which course has been viewed by SA ?
# distance = 0.0000
# --------------------------------------------------
# Comparing to: SA has viewed course CS260 Human Computer Interaction
# distance = 0.5430
# --------------------------------------------------
# Comparing to: MH has viewed course CS260 Human Computer Interaction
# distance = 0.7839
# --------------------------------------------------
# Comparing to: HM has viewed course CS260 Human Computer Interaction
# distance = 0.7616
#
# Question: which course has been viewed by AHK ?
#
# --------------------------------------------------
# Comparing to: which course has been viewed by AHK ?
# distance = 0.0000
# --------------------------------------------------
# Comparing to: HM has viewed course CS260 Human Computer Interaction
# distance = 0.7963
# --------------------------------------------------
# Comparing to: AHK has viewed course CS260 Human Computer Interaction
# distance = 0.5604
# --------------------------------------------------
# Comparing to: SA enrolled to CS260 Human Computer Interaction and SA has viewed course CS260 Human Computer Interaction
# distance = 0.9485
#
# Question: who is enrolled to CS260 Human Computer Interaction course ?
#
# --------------------------------------------------
# Comparing to: who is enrolled to CS260 Human Computer Interaction course ?
# distance = 0.0000
# --------------------------------------------------
# Comparing to: NSC enrolled to CS260 Human Computer Interaction and NSC has viewed course CS260 Human Computer Interaction
# distance = 0.3886
# --------------------------------------------------
# Comparing to: MFF has viewed course CS260 Human Computer Interaction and ANB has viewed course CS260 Human Computer Interaction
# distance = 0.4293
# --------------------------------------------------
# Comparing to: AS has viewed course CS260 Human Computer Interaction
# distance = 0.3774
#
# Question: which course has been viewed by DA ?
#
# --------------------------------------------------
# Comparing to: which course has been viewed by DA ?
# distance = 0.0000
# --------------------------------------------------
# Comparing to: UZ has viewed course CS260 Human Computer Interaction and UZ enrolled to CS260 Human Computer Interaction
# distance = 0.9102
# --------------------------------------------------
# Comparing to: SA has viewed course CS260 Human Computer Interaction
# distance = 0.7136
# --------------------------------------------------
# Comparing to: DA has viewed course Geography
# distance = 0.2973
#
# Question: which course has been viewed by SMH ?
#
# --------------------------------------------------
# Comparing to: which course has been viewed by SMH ?
# distance = 0.0000
# --------------------------------------------------
# Comparing to: AM has viewed resource CS260Lecture1Rules Regulations and AM has viewed resource CS260Lecture2Introduction HCI and AM has viewed resource CS260Lecture1Rules Regulations and AM has viewed resource CS260Lecture2Introduction HCI
# distance = 0.8959
# --------------------------------------------------
# Comparing to: SMH has viewed course CS260 Human Computer Interaction
# distance = 0.5378
# --------------------------------------------------
# Comparing to: AM has viewed course CS260 Human Computer Interaction
# distance = 0.6892
#
# Question: which course has been viewed by HM or MA ?
#
# --------------------------------------------------
# Comparing to: which course has been viewed by HM or MA ?
# distance = 0.0000
# --------------------------------------------------
# Comparing to: HM has viewed course CS260 Human Computer Interaction
# distance = 0.5602
# --------------------------------------------------
# Comparing to: MMA has viewed course CS260 Human Computer Interaction and MMA has viewed course CS260Lecture1Rules Regulations and MMA has viewed course CS260Lecture2Introduction HCI and MMA has viewed resource CS260 Human Computer Interaction and MMA has viewed resource CS260Lecture1Rules Regulations and MMA has viewed resource CS260Lecture2Introduction HCI and MMA has viewed resource CS260 Human Computer Interaction and MMA has viewed resource CS260Lecture1Rules Regulations and MMA has viewed resource CS260Lecture2Introduction HCI
# distance = 0.8716
# --------------------------------------------------
# Comparing to: MA has viewed course CS260 Human Computer Interaction
# distance = 0.6057
#
# Question: who is enrolled to CS260 Human Computer Interaction course ?
#
# --------------------------------------------------
# Comparing to: who is enrolled to CS260 Human Computer Interaction course ?
# distance = 0.0000
# --------------------------------------------------
# Comparing to: SA has viewed resource CS260Lecture1Rules Regulations and SA has viewed resource CS260 Human Computer Interaction and SA has viewed course CS260Lecture1Rules Regulations and SA has viewed course CS260 Human Computer Interaction
# distance = 0.6889
# --------------------------------------------------
# Comparing to: NSC enrolled to CS260 Human Computer Interaction and NSC has viewed course CS260 Human Computer Interaction
# distance = 0.3886
# --------------------------------------------------
# Comparing to: KK has viewed course CS260 Human Computer Interaction and HM has viewed course CS260 Human Computer Interaction and HM enrolled to CS260 Human Computer Interaction and DA enrolled to CS260 Human Computer Interaction
# distance = 0.3949
#
# Question: which course have been viewed by MMA ?
#
# --------------------------------------------------
# Comparing to: which course have been viewed by MMA ?
# distance = 0.0000
# --------------------------------------------------
# Comparing to: MMA has viewed course CS260 Human Computer Interaction and MMA enrolled to CS260 Human Computer Interaction
# distance = 0.6717
# --------------------------------------------------
# Comparing to: MMA has viewed Geography and MMA has viewed course CS260Lecture1Rules Regulations and MMA has viewed course CS260Lecture2Introduction HCI and MMA has viewed resource CS260 Human Computer Knwoledge and MMA has viewed resource CS260Lecture1 Mathematics and MMA has viewed resource CS260Lecture2 Mathematics and MMA has viewed resource CS260 Human Computer Interaction and MMA has viewed resource CS260Lecture3 Mathematics and MMA has viewed resource CS260Lecture4 Mathematics
# distance = 0.5226
# --------------------------------------------------
# Comparing to: ANB has viewed course CS260 Human Computer Interaction
# distance = 0.7402
#
# Question: which course has been viewed by MS ?
#
# --------------------------------------------------
# Comparing to: which course has been viewed by MS ?
# distance = 0.0000
# --------------------------------------------------
# Comparing to: SA has viewed resource CS260Lecture1Rules Regulations and SA has viewed resource CS260 Human Computer Interaction and SA has viewed course CS260Lecture1Rules Regulations and SA has viewed course CS260 Human Computer Interaction
# distance = 0.7925
# --------------------------------------------------
# Comparing to: MS has viewed course CS260 Human Computer Interaction and MS has viewed course CS260Lecture2Introduction HCI and MS has viewed resource CS260 Human Computer Interaction and MS has viewed resource CS260Lecture2Introduction HCI
# distance = 0.5635
# --------------------------------------------------
# Comparing to: AM has viewed course CS260 Human Computer Interaction
# distance = 0.6673
#
# Question: who is enrolled to CS260 Human Computer Interaction course ?
#
# --------------------------------------------------
# Comparing to: who is enrolled to CS260 Human Computer Interaction course ?
# distance = 0.0000
# --------------------------------------------------
# Comparing to: AM has viewed course CS260 Human Computer Interaction
# distance = 0.3774
# --------------------------------------------------
# Comparing to: RAK enrolled to CS260 Human Computer Interaction and RAK has viewed course CS260 Human Computer Interaction
# distance = 0.4070
# --------------------------------------------------
# Comparing to: KK has viewed course CS260 Human Computer Interaction and HM has viewed course CS260 Human Computer Interaction and HM enrolled to CS260 Human Computer Interaction and DA enrolled to CS260 Human Computer Interaction
# distance = 0.3949
#
# Question: Which course SA has viewed ?
#
# --------------------------------------------------
# Comparing to: Which course SA has viewed ?
# distance = 0.0000
# --------------------------------------------------
# Comparing to: SA has viewed course CS260 Human Computer Interaction
# distance = 0.5430
# --------------------------------------------------
# Comparing to: ANB has viewed course CS260 Human Computer Interaction
# distance = 0.7692
# --------------------------------------------------
# Comparing to: HM has viewed course CS260 Human Computer Interaction
# distance = 0.7616
#
# Question: Who viewed the CS260 Human Computer Interaction course ?
#
# --------------------------------------------------
# Comparing to: Who viewed the CS260 Human Computer Interaction course ?
# distance = 0.0000
# --------------------------------------------------
# Comparing to: ANB has viewed course CS260 Human Computer Interaction
# distance = 0.2552
# --------------------------------------------------
# Comparing to: MOJ has viewed resource CS260Lecture2Introduction HCI and MOJ has viewed resource CS260 Human Computer Interaction and HS has viewed course CS260Lecture2Introduction HCI and HS has viewed course CS260 Human Computer Interaction
# distance = 0.5340
# --------------------------------------------------
# Comparing to: RAK has viewed course CS260 Human Computer Interaction
# distance = 0.2369
#
# Question: Which course has UZ viewed ?
#
# --------------------------------------------------
# Comparing to: Which course has UZ viewed ?
# distance = 0.0000
# --------------------------------------------------
# Comparing to: UZ has viewed course CS260 Human Computer Interaction
# distance = 0.5504
# --------------------------------------------------
# Comparing to: UZ has viewed course Mathematics and UZ enrolled to CS260 Human Computer Interaction
# distance = 0.5874
# --------------------------------------------------
# Comparing to: SA has viewed course CS260 Human Computer Interaction
# distance = 0.7596
#
# Question: Which course has SA viewed ?
#
# --------------------------------------------------
# Comparing to: Which course has SA viewed ?
# distance = 0.0000
# --------------------------------------------------
# Comparing to: SA has viewed course CS260 Human Computer Interaction
# distance = 0.5430
# --------------------------------------------------
# Comparing to: KK has viewed course CS260 Human Computer Interaction
# distance = 0.7306
# --------------------------------------------------
# Comparing to: ANB has viewed course CS260 Human Computer Interaction
# distance = 0.7692
#
# Question: who added resource 125052 ?
#
# --------------------------------------------------
# Comparing to: who added resource 125052 ?
# distance = 0.0000
# --------------------------------------------------
# Comparing to: ANB added 125052 and CS260 Human Computer Interaction course
# distance = 0.8501
# --------------------------------------------------
# Comparing to: SA has viewed course CS260 Human Computer Interaction
# distance = 0.9894
# --------------------------------------------------
# Comparing to: KAP has viewed course CS260 Human Computer Interaction and KAP has viewed course CS260Lecture1Rules Regulations and KAP has viewed course CS260Lecture2Introduction HCI and KAP has viewed resource CS260 Human Computer Interaction and KAP has viewed resource CS260Lecture1Rules Regulations and KAP has viewed resource CS260Lecture2Introduction HCI and KAP has viewed resource CS260 Human Computer Interaction and KAP has viewed resource CS260Lecture1Rules Regulations and KAP has viewed resource CS260Lecture2Introduction HCI
# distance = 0.9936
